# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models,utils
import matplotlib.pyplot as plt
import numpy as np
import librosa 
import librosa.display
import IPython.display as ipd
import resampy
from resampy import resample

# %%
import pandas as pd
import os 


audio_dataset_path='audio_dataset/'
metadata=pd.read_csv('metadata3.csv')
# Out:
#    file_name_1  classid       class  fold
# 0   bear_1.wav        1  bear_fault     1
# 1  bear_10.wav        1  bear_fault     1
# 2  bear_11.wav        1  bear_fault     1
# 3  bear_12.wav        1  bear_fault     1
# 4  bear_13.wav        1  bear_fault     1

# %%
def features_extractor(file):
    audio,sample_rate=librosa.load(file_name,res_type='kaiser_fast')
    mfccs_features=librosa.feature.mfcc(y=audio,sr=sample_rate,n_mfcc=40)
    mfccs_scaled_features=np.mean(mfccs_features.T,axis=0)
    return mfccs_scaled_features

# %%
from tqdm import tqdm 


extracted_features=[]
for index_num,row in tqdm(metadata.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path),'fold'+str(row["fold"])+'/',str(row["file_name_1"]))
    final_class_labels=row["class"]
    data=features_extractor(file_name)
    extracted_features.append([data,final_class_labels])
# Out:
# 210it [01:18,  2.68it/s]

# %%
extracted_features_df=pd.DataFrame(extracted_features,columns=['feature','class'])

# %%
X=np.array(extracted_features_df['feature'].tolist())
y=np.array(extracted_features_df['class'].tolist())

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
y=to_categorical(labelencoder.fit_transform(y))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.optimizers import Adam
from sklearn import metrics

# %%
# Dense()
num_labels=y.shape[1]

# %%
model=Sequential()
###first layer
model.add(Dense(100,input_shape=(40,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###second layer
model.add(Dense(200))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###third layer
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dropout(0.5))

###final layer
model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')

# %%
#training the model

from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime 

num_epochs = 100
num_batch_size = 32

checkpointer = ModelCheckpoint(filepath='saved_models/audio_classification.hdf5', 
                               verbose=1, save_best_only=True)
start = datetime.now()

model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test, y_test), callbacks=[checkpointer], verbose=1)


duration = datetime.now() - start
# Out:
# Epoch 1/100
# 1/6 [====>.........................] - ETA: 3s - loss: 22.8174 - accuracy: 0.3438
# Epoch 1: val_loss improved from inf to 4.07251, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 1s 47ms/step - loss: 19.3332 - accuracy: 0.3095 - val_loss: 4.0725 - val_accuracy: 0.5952
# Epoch 2/100
# 1/6 [====>.........................] - ETA: 0s - loss: 14.8841 - accuracy: 0.3438
# Epoch 2: val_loss did not improve from 4.07251
# 6/6 [==============================] - 0s 9ms/step - loss: 14.9980 - accuracy: 0.4107 - val_loss: 4.2781 - val_accuracy: 0.5000
# Epoch 3/100
# 1/6 [====>.........................] - ETA: 0s - loss: 18.0335 - accuracy: 0.3125
# Epoch 3: val_loss improved from 4.07251 to 1.53123, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 12.1138 - accuracy: 0.4226 - val_loss: 1.5312 - val_accuracy: 0.6667
# Epoch 4/100
# 1/6 [====>.........................] - ETA: 0s - loss: 11.7315 - accuracy: 0.3750
# Epoch 4: val_loss improved from 1.53123 to 0.82973, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 10.4767 - accuracy: 0.3512 - val_loss: 0.8297 - val_accuracy: 0.6905
# Epoch 5/100
# 1/6 [====>.........................] - ETA: 0s - loss: 9.3476 - accuracy: 0.4062
# Epoch 5: val_loss improved from 0.82973 to 0.72130, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 8.4179 - accuracy: 0.4167 - val_loss: 0.7213 - val_accuracy: 0.6905
# Epoch 6/100
# 1/6 [====>.........................] - ETA: 0s - loss: 8.7876 - accuracy: 0.4375
# Epoch 6: val_loss improved from 0.72130 to 0.70496, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 6.3043 - accuracy: 0.4940 - val_loss: 0.7050 - val_accuracy: 0.7143
# Epoch 7/100
# 1/6 [====>.........................] - ETA: 0s - loss: 5.1984 - accuracy: 0.5000
# Epoch 7: val_loss did not improve from 0.70496
# 6/6 [==============================] - 0s 9ms/step - loss: 6.0875 - accuracy: 0.4524 - val_loss: 0.7166 - val_accuracy: 0.7143
# Epoch 8/100
# 1/6 [====>.........................] - ETA: 0s - loss: 5.0973 - accuracy: 0.4688
# Epoch 8: val_loss improved from 0.70496 to 0.67445, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 4.9895 - accuracy: 0.5119 - val_loss: 0.6744 - val_accuracy: 0.6905
# Epoch 9/100
# 1/6 [====>.........................] - ETA: 0s - loss: 6.1317 - accuracy: 0.5625
# Epoch 9: val_loss improved from 0.67445 to 0.62551, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 5.5041 - accuracy: 0.5357 - val_loss: 0.6255 - val_accuracy: 0.7143
# Epoch 10/100
# 1/6 [====>.........................] - ETA: 0s - loss: 5.0201 - accuracy: 0.5625
# Epoch 10: val_loss improved from 0.62551 to 0.62530, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 4.2480 - accuracy: 0.5476 - val_loss: 0.6253 - val_accuracy: 0.7619
# Epoch 11/100
# 1/6 [====>.........................] - ETA: 0s - loss: 4.5916 - accuracy: 0.5625
# Epoch 11: val_loss improved from 0.62530 to 0.57921, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 3.7825 - accuracy: 0.5357 - val_loss: 0.5792 - val_accuracy: 0.7619
# Epoch 12/100
# 1/6 [====>.........................] - ETA: 0s - loss: 3.9675 - accuracy: 0.4375
# Epoch 12: val_loss improved from 0.57921 to 0.52505, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 4.0471 - accuracy: 0.4643 - val_loss: 0.5250 - val_accuracy: 0.8095
# Epoch 13/100
# 1/6 [====>.........................] - ETA: 0s - loss: 3.2474 - accuracy: 0.5312
# Epoch 13: val_loss improved from 0.52505 to 0.49543, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 3.1430 - accuracy: 0.5476 - val_loss: 0.4954 - val_accuracy: 0.8571
# Epoch 14/100
# 1/6 [====>.........................] - ETA: 0s - loss: 3.7069 - accuracy: 0.6562
# Epoch 14: val_loss improved from 0.49543 to 0.48179, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 3.2411 - accuracy: 0.5774 - val_loss: 0.4818 - val_accuracy: 0.8810
# Epoch 15/100
# 1/6 [====>.........................] - ETA: 0s - loss: 3.0875 - accuracy: 0.3750
# Epoch 15: val_loss improved from 0.48179 to 0.47070, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 3.0551 - accuracy: 0.4821 - val_loss: 0.4707 - val_accuracy: 0.8810
# Epoch 16/100
# 1/6 [====>.........................] - ETA: 0s - loss: 2.6766 - accuracy: 0.5312
# Epoch 16: val_loss improved from 0.47070 to 0.46957, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 2.6474 - accuracy: 0.5417 - val_loss: 0.4696 - val_accuracy: 0.8810
# Epoch 17/100
# 1/6 [====>.........................] - ETA: 0s - loss: 2.7794 - accuracy: 0.5938
# Epoch 17: val_loss did not improve from 0.46957
# 6/6 [==============================] - 0s 9ms/step - loss: 2.6053 - accuracy: 0.5833 - val_loss: 0.4736 - val_accuracy: 0.9048
# Epoch 18/100
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0083 - accuracy: 0.6250
# Epoch 18: val_loss improved from 0.46957 to 0.46743, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 14ms/step - loss: 1.8978 - accuracy: 0.5714 - val_loss: 0.4674 - val_accuracy: 0.8810
# Epoch 19/100
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7511 - accuracy: 0.5938
# Epoch 19: val_loss improved from 0.46743 to 0.46021, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 1.8349 - accuracy: 0.6012 - val_loss: 0.4602 - val_accuracy: 0.8810
# Epoch 20/100
# 1/6 [====>.........................] - ETA: 0s - loss: 2.2425 - accuracy: 0.6250
# Epoch 20: val_loss improved from 0.46021 to 0.45667, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 1.9948 - accuracy: 0.6310 - val_loss: 0.4567 - val_accuracy: 0.8810
# Epoch 21/100
# 1/6 [====>.........................] - ETA: 0s - loss: 1.8774 - accuracy: 0.5312
# Epoch 21: val_loss improved from 0.45667 to 0.45062, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 1.9633 - accuracy: 0.5774 - val_loss: 0.4506 - val_accuracy: 0.8571
# Epoch 22/100
# 1/6 [====>.........................] - ETA: 0s - loss: 3.2438 - accuracy: 0.4375
# Epoch 22: val_loss improved from 0.45062 to 0.39342, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 2.1219 - accuracy: 0.5536 - val_loss: 0.3934 - val_accuracy: 0.8810
# Epoch 23/100
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5590 - accuracy: 0.6250
# Epoch 23: val_loss improved from 0.39342 to 0.37232, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 1.6716 - accuracy: 0.6726 - val_loss: 0.3723 - val_accuracy: 0.8571
# Epoch 24/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.9269 - accuracy: 0.7500
# Epoch 24: val_loss improved from 0.37232 to 0.37162, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 14ms/step - loss: 1.6692 - accuracy: 0.6369 - val_loss: 0.3716 - val_accuracy: 0.8810
# Epoch 25/100
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7419 - accuracy: 0.6875
# Epoch 25: val_loss did not improve from 0.37162
# 6/6 [==============================] - 0s 9ms/step - loss: 1.6384 - accuracy: 0.6786 - val_loss: 0.3725 - val_accuracy: 0.8810
# Epoch 26/100
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4720 - accuracy: 0.5312
# Epoch 26: val_loss did not improve from 0.37162
# 6/6 [==============================] - 0s 9ms/step - loss: 1.4948 - accuracy: 0.6250 - val_loss: 0.3868 - val_accuracy: 0.8571
# Epoch 27/100
# 1/6 [====>.........................] - ETA: 0s - loss: 1.3900 - accuracy: 0.5625
# Epoch 27: val_loss did not improve from 0.37162
# 6/6 [==============================] - 0s 9ms/step - loss: 1.7566 - accuracy: 0.6131 - val_loss: 0.3884 - val_accuracy: 0.8571
# Epoch 28/100
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0727 - accuracy: 0.6250
# Epoch 28: val_loss did not improve from 0.37162
# 6/6 [==============================] - 0s 10ms/step - loss: 1.4968 - accuracy: 0.6488 - val_loss: 0.3739 - val_accuracy: 0.8333
# Epoch 29/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.9128 - accuracy: 0.7188
# Epoch 29: val_loss improved from 0.37162 to 0.35698, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 1.0611 - accuracy: 0.6786 - val_loss: 0.3570 - val_accuracy: 0.8810
# Epoch 30/100
# 1/6 [====>.........................] - ETA: 0s - loss: 1.2576 - accuracy: 0.6875
# Epoch 30: val_loss improved from 0.35698 to 0.35163, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 14ms/step - loss: 1.3504 - accuracy: 0.6607 - val_loss: 0.3516 - val_accuracy: 0.8571
# Epoch 31/100
# 1/6 [====>.........................] - ETA: 0s - loss: 1.8742 - accuracy: 0.5625
# Epoch 31: val_loss improved from 0.35163 to 0.34809, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 1.3566 - accuracy: 0.6250 - val_loss: 0.3481 - val_accuracy: 0.8571
# Epoch 32/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.5658 - accuracy: 0.8438
# Epoch 32: val_loss improved from 0.34809 to 0.34770, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 14ms/step - loss: 1.0615 - accuracy: 0.7143 - val_loss: 0.3477 - val_accuracy: 0.8571
# Epoch 33/100
# 1/6 [====>.........................] - ETA: 0s - loss: 1.2277 - accuracy: 0.5312
# Epoch 33: val_loss did not improve from 0.34770
# 6/6 [==============================] - 0s 9ms/step - loss: 1.1193 - accuracy: 0.6548 - val_loss: 0.3583 - val_accuracy: 0.8571
# Epoch 34/100
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5809 - accuracy: 0.5625
# Epoch 34: val_loss did not improve from 0.34770
# 6/6 [==============================] - 0s 9ms/step - loss: 1.2131 - accuracy: 0.6726 - val_loss: 0.3562 - val_accuracy: 0.8810
# Epoch 35/100
# 1/6 [====>.........................] - ETA: 0s - loss: 1.2833 - accuracy: 0.5938
# Epoch 35: val_loss did not improve from 0.34770
# 6/6 [==============================] - 0s 9ms/step - loss: 0.9193 - accuracy: 0.7202 - val_loss: 0.3493 - val_accuracy: 0.8810
# Epoch 36/100
# 1/6 [====>.........................] - ETA: 0s - loss: 1.1139 - accuracy: 0.6250
# Epoch 36: val_loss improved from 0.34770 to 0.34731, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 1.1270 - accuracy: 0.6369 - val_loss: 0.3473 - val_accuracy: 0.9048
# Epoch 37/100
# 1/6 [====>.........................] - ETA: 0s - loss: 1.0386 - accuracy: 0.7500
# Epoch 37: val_loss improved from 0.34731 to 0.32881, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 14ms/step - loss: 0.9353 - accuracy: 0.6726 - val_loss: 0.3288 - val_accuracy: 0.9048
# Epoch 38/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.9104 - accuracy: 0.7188
# Epoch 38: val_loss improved from 0.32881 to 0.31449, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 1.2067 - accuracy: 0.6667 - val_loss: 0.3145 - val_accuracy: 0.9048
# Epoch 39/100
# 1/6 [====>.........................] - ETA: 0s - loss: 1.0394 - accuracy: 0.6875
# Epoch 39: val_loss improved from 0.31449 to 0.30608, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 0.7778 - accuracy: 0.7262 - val_loss: 0.3061 - val_accuracy: 0.9524
# Epoch 40/100
# 1/6 [====>.........................] - ETA: 0s - loss: 1.1847 - accuracy: 0.5625
# Epoch 40: val_loss improved from 0.30608 to 0.30427, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.9742 - accuracy: 0.6726 - val_loss: 0.3043 - val_accuracy: 0.9286
# Epoch 41/100
# 1/6 [====>.........................] - ETA: 0s - loss: 1.0684 - accuracy: 0.6875
# Epoch 41: val_loss improved from 0.30427 to 0.30021, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 14ms/step - loss: 0.8648 - accuracy: 0.7560 - val_loss: 0.3002 - val_accuracy: 0.9524
# Epoch 42/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.9662 - accuracy: 0.6562
# Epoch 42: val_loss improved from 0.30021 to 0.29519, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 1.0200 - accuracy: 0.7619 - val_loss: 0.2952 - val_accuracy: 0.9524
# Epoch 43/100
# 1/6 [====>.........................] - ETA: 0s - loss: 1.3149 - accuracy: 0.6250
# Epoch 43: val_loss improved from 0.29519 to 0.28624, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 0.8509 - accuracy: 0.7321 - val_loss: 0.2862 - val_accuracy: 0.9524
# Epoch 44/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.6959 - accuracy: 0.7812
# Epoch 44: val_loss improved from 0.28624 to 0.28143, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.7934 - accuracy: 0.7738 - val_loss: 0.2814 - val_accuracy: 0.9524
# Epoch 45/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.8479 - accuracy: 0.7188
# Epoch 45: val_loss improved from 0.28143 to 0.27598, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 0.8743 - accuracy: 0.7440 - val_loss: 0.2760 - val_accuracy: 0.9524
# Epoch 46/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.8542 - accuracy: 0.7812
# Epoch 46: val_loss improved from 0.27598 to 0.27028, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.8324 - accuracy: 0.7143 - val_loss: 0.2703 - val_accuracy: 0.9524
# Epoch 47/100
# 1/6 [====>.........................] - ETA: 0s - loss: 1.2626 - accuracy: 0.5625
# Epoch 47: val_loss did not improve from 0.27028
# 6/6 [==============================] - 0s 9ms/step - loss: 0.7173 - accuracy: 0.7440 - val_loss: 0.2706 - val_accuracy: 0.9524
# Epoch 48/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.4145 - accuracy: 0.9062
# Epoch 48: val_loss improved from 0.27028 to 0.26452, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5929 - accuracy: 0.7798 - val_loss: 0.2645 - val_accuracy: 0.9524
# Epoch 49/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.4117 - accuracy: 0.8438
# Epoch 49: val_loss improved from 0.26452 to 0.25516, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 0.7119 - accuracy: 0.7560 - val_loss: 0.2552 - val_accuracy: 0.9524
# Epoch 50/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.5053 - accuracy: 0.9062
# Epoch 50: val_loss improved from 0.25516 to 0.24551, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.7234 - accuracy: 0.7976 - val_loss: 0.2455 - val_accuracy: 0.9524
# Epoch 51/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.7414 - accuracy: 0.6875
# Epoch 51: val_loss improved from 0.24551 to 0.24069, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.8076 - accuracy: 0.7619 - val_loss: 0.2407 - val_accuracy: 0.9524
# Epoch 52/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.5323 - accuracy: 0.8438
# Epoch 52: val_loss improved from 0.24069 to 0.23808, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.6766 - accuracy: 0.7679 - val_loss: 0.2381 - val_accuracy: 0.9524
# Epoch 53/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.5845 - accuracy: 0.8438
# Epoch 53: val_loss improved from 0.23808 to 0.23475, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.6923 - accuracy: 0.7560 - val_loss: 0.2347 - val_accuracy: 0.9524
# Epoch 54/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.5864 - accuracy: 0.8750
# Epoch 54: val_loss improved from 0.23475 to 0.23027, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 14ms/step - loss: 0.6902 - accuracy: 0.7381 - val_loss: 0.2303 - val_accuracy: 0.9524
# Epoch 55/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.4874 - accuracy: 0.7812
# Epoch 55: val_loss improved from 0.23027 to 0.23007, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5586 - accuracy: 0.7738 - val_loss: 0.2301 - val_accuracy: 0.9524
# Epoch 56/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3997 - accuracy: 0.8438
# Epoch 56: val_loss did not improve from 0.23007
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5135 - accuracy: 0.8214 - val_loss: 0.2306 - val_accuracy: 0.9524
# Epoch 57/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.2602 - accuracy: 0.8750
# Epoch 57: val_loss improved from 0.23007 to 0.22875, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6387 - accuracy: 0.7619 - val_loss: 0.2287 - val_accuracy: 0.9524
# Epoch 58/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.6691 - accuracy: 0.8125
# Epoch 58: val_loss improved from 0.22875 to 0.22820, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5294 - accuracy: 0.8333 - val_loss: 0.2282 - val_accuracy: 0.9524
# Epoch 59/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.5989 - accuracy: 0.8438
# Epoch 59: val_loss improved from 0.22820 to 0.22240, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5725 - accuracy: 0.8274 - val_loss: 0.2224 - val_accuracy: 0.9524
# Epoch 60/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.5801 - accuracy: 0.8438
# Epoch 60: val_loss improved from 0.22240 to 0.21907, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6977 - accuracy: 0.7738 - val_loss: 0.2191 - val_accuracy: 0.9524
# Epoch 61/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3260 - accuracy: 0.8438
# Epoch 61: val_loss improved from 0.21907 to 0.21891, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4760 - accuracy: 0.8155 - val_loss: 0.2189 - val_accuracy: 0.9524
# Epoch 62/100
# 1/6 [====>.........................] - ETA: 0s - loss: 1.0929 - accuracy: 0.7812
# Epoch 62: val_loss improved from 0.21891 to 0.21641, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.7056 - accuracy: 0.7679 - val_loss: 0.2164 - val_accuracy: 0.9524
# Epoch 63/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3922 - accuracy: 0.8750
# Epoch 63: val_loss improved from 0.21641 to 0.21256, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4247 - accuracy: 0.8571 - val_loss: 0.2126 - val_accuracy: 0.9524
# Epoch 64/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.4925 - accuracy: 0.8750
# Epoch 64: val_loss improved from 0.21256 to 0.21047, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4781 - accuracy: 0.8333 - val_loss: 0.2105 - val_accuracy: 0.9524
# Epoch 65/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.4263 - accuracy: 0.8750
# Epoch 65: val_loss improved from 0.21047 to 0.20877, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5111 - accuracy: 0.8155 - val_loss: 0.2088 - val_accuracy: 0.9524
# Epoch 66/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.4330 - accuracy: 0.8750
# Epoch 66: val_loss did not improve from 0.20877
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4895 - accuracy: 0.8274 - val_loss: 0.2095 - val_accuracy: 0.9524
# Epoch 67/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.2952 - accuracy: 0.8750
# Epoch 67: val_loss did not improve from 0.20877
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5195 - accuracy: 0.7738 - val_loss: 0.2121 - val_accuracy: 0.9524
# Epoch 68/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.6725 - accuracy: 0.7812
# Epoch 68: val_loss did not improve from 0.20877
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5609 - accuracy: 0.7738 - val_loss: 0.2173 - val_accuracy: 0.9524
# Epoch 69/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3258 - accuracy: 0.9062
# Epoch 69: val_loss did not improve from 0.20877
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4585 - accuracy: 0.8571 - val_loss: 0.2188 - val_accuracy: 0.9524
# Epoch 70/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3666 - accuracy: 0.8438
# Epoch 70: val_loss did not improve from 0.20877
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4174 - accuracy: 0.8155 - val_loss: 0.2132 - val_accuracy: 0.9524
# Epoch 71/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.5328 - accuracy: 0.8125
# Epoch 71: val_loss improved from 0.20877 to 0.20657, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5006 - accuracy: 0.8512 - val_loss: 0.2066 - val_accuracy: 0.9524
# Epoch 72/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3391 - accuracy: 0.8438
# Epoch 72: val_loss improved from 0.20657 to 0.20223, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3231 - accuracy: 0.8810 - val_loss: 0.2022 - val_accuracy: 0.9524
# Epoch 73/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3996 - accuracy: 0.8125
# Epoch 73: val_loss did not improve from 0.20223
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5230 - accuracy: 0.8155 - val_loss: 0.2051 - val_accuracy: 0.9524
# Epoch 74/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.5883 - accuracy: 0.8438
# Epoch 74: val_loss did not improve from 0.20223
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4468 - accuracy: 0.8393 - val_loss: 0.2226 - val_accuracy: 0.9524
# Epoch 75/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.5371 - accuracy: 0.7500
# Epoch 75: val_loss did not improve from 0.20223
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3649 - accuracy: 0.8274 - val_loss: 0.2295 - val_accuracy: 0.9286
# Epoch 76/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.5044 - accuracy: 0.8125
# Epoch 76: val_loss did not improve from 0.20223
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4077 - accuracy: 0.8571 - val_loss: 0.2284 - val_accuracy: 0.9286
# Epoch 77/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.2696 - accuracy: 0.8750
# Epoch 77: val_loss did not improve from 0.20223
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3799 - accuracy: 0.8571 - val_loss: 0.2276 - val_accuracy: 0.9048
# Epoch 78/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.6628 - accuracy: 0.8125
# Epoch 78: val_loss did not improve from 0.20223
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4920 - accuracy: 0.8155 - val_loss: 0.2305 - val_accuracy: 0.9048
# Epoch 79/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3994 - accuracy: 0.8125
# Epoch 79: val_loss did not improve from 0.20223
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4551 - accuracy: 0.8095 - val_loss: 0.2229 - val_accuracy: 0.9048
# Epoch 80/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.2730 - accuracy: 0.9062
# Epoch 80: val_loss did not improve from 0.20223
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4907 - accuracy: 0.8512 - val_loss: 0.2088 - val_accuracy: 0.9286
# Epoch 81/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.5064 - accuracy: 0.7812
# Epoch 81: val_loss improved from 0.20223 to 0.19317, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3388 - accuracy: 0.8810 - val_loss: 0.1932 - val_accuracy: 0.9524
# Epoch 82/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.2947 - accuracy: 0.8438
# Epoch 82: val_loss improved from 0.19317 to 0.18033, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4442 - accuracy: 0.8393 - val_loss: 0.1803 - val_accuracy: 0.9524
# Epoch 83/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3564 - accuracy: 0.9062
# Epoch 83: val_loss improved from 0.18033 to 0.17073, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4052 - accuracy: 0.8571 - val_loss: 0.1707 - val_accuracy: 0.9524
# Epoch 84/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3315 - accuracy: 0.8750
# Epoch 84: val_loss improved from 0.17073 to 0.16650, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4318 - accuracy: 0.8571 - val_loss: 0.1665 - val_accuracy: 0.9524
# Epoch 85/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.5176 - accuracy: 0.7812
# Epoch 85: val_loss improved from 0.16650 to 0.16396, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3124 - accuracy: 0.8631 - val_loss: 0.1640 - val_accuracy: 0.9524
# Epoch 86/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.4103 - accuracy: 0.8438
# Epoch 86: val_loss improved from 0.16396 to 0.15954, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3371 - accuracy: 0.8929 - val_loss: 0.1595 - val_accuracy: 0.9524
# Epoch 87/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.2054 - accuracy: 0.8750
# Epoch 87: val_loss improved from 0.15954 to 0.15516, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2840 - accuracy: 0.8869 - val_loss: 0.1552 - val_accuracy: 0.9524
# Epoch 88/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3646 - accuracy: 0.7812
# Epoch 88: val_loss improved from 0.15516 to 0.14886, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3613 - accuracy: 0.8571 - val_loss: 0.1489 - val_accuracy: 0.9524
# Epoch 89/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.2382 - accuracy: 0.9062
# Epoch 89: val_loss improved from 0.14886 to 0.14763, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3433 - accuracy: 0.8452 - val_loss: 0.1476 - val_accuracy: 0.9524
# Epoch 90/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.4149 - accuracy: 0.9062
# Epoch 90: val_loss did not improve from 0.14763
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3452 - accuracy: 0.8750 - val_loss: 0.1509 - val_accuracy: 0.9524
# Epoch 91/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.5080 - accuracy: 0.8438
# Epoch 91: val_loss did not improve from 0.14763
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3708 - accuracy: 0.8571 - val_loss: 0.1585 - val_accuracy: 0.9524
# Epoch 92/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.1882 - accuracy: 0.9375
# Epoch 92: val_loss did not improve from 0.14763
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2565 - accuracy: 0.8929 - val_loss: 0.1675 - val_accuracy: 0.9524
# Epoch 93/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.1905 - accuracy: 0.9375
# Epoch 93: val_loss did not improve from 0.14763
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2874 - accuracy: 0.8690 - val_loss: 0.1675 - val_accuracy: 0.9524
# Epoch 94/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.2853 - accuracy: 0.8750
# Epoch 94: val_loss did not improve from 0.14763
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3032 - accuracy: 0.8512 - val_loss: 0.1626 - val_accuracy: 0.9524
# Epoch 95/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.2329 - accuracy: 0.9375
# Epoch 95: val_loss did not improve from 0.14763
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3214 - accuracy: 0.8690 - val_loss: 0.1561 - val_accuracy: 0.9524
# Epoch 96/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.4275 - accuracy: 0.8438
# Epoch 96: val_loss did not improve from 0.14763
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3339 - accuracy: 0.8750 - val_loss: 0.1495 - val_accuracy: 0.9524
# Epoch 97/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.2891 - accuracy: 0.8750
# Epoch 97: val_loss improved from 0.14763 to 0.14166, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3634 - accuracy: 0.8631 - val_loss: 0.1417 - val_accuracy: 0.9524
# Epoch 98/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3444 - accuracy: 0.9062
# Epoch 98: val_loss improved from 0.14166 to 0.13707, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 0.2280 - accuracy: 0.9107 - val_loss: 0.1371 - val_accuracy: 0.9524
# Epoch 99/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.3017 - accuracy: 0.9062
# Epoch 99: val_loss improved from 0.13707 to 0.13289, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 12ms/step - loss: 0.2590 - accuracy: 0.9048 - val_loss: 0.1329 - val_accuracy: 0.9524
# Epoch 100/100
# 1/6 [====>.........................] - ETA: 0s - loss: 0.4418 - accuracy: 0.9062
# Epoch 100: val_loss improved from 0.13289 to 0.12967, saving model to saved_models\audio_classification.hdf5
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2569 - accuracy: 0.9226 - val_loss: 0.1297 - val_accuracy: 0.9524

# %%
def classify():
    filename="gear_2.wav"
    audio, sample_rate = librosa.load(filename, res_type='kaiser_fast') 
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    print(mfccs_scaled_features)
    mfccs_scaled_features=mfccs_scaled_features.reshape(1,-1)
    print(mfccs_scaled_features)
    print(mfccs_scaled_features.shape)
    predicted_label=np.argmax(model.predict(mfccs_scaled_features),axis=-1)
    print(predicted_label)
    prediction_class = labelencoder.inverse_transform(predicted_label) 
    prediction_class
# Out:
# [-51.242413    49.093845   -18.26149      3.055037   -22.694397
#    4.807211   -19.459581    14.904933   -29.962736    -3.8382246
#   -9.103179    17.830744   -22.41513     14.5221     -16.380196
#    4.0303774  -18.906586     9.933028    -8.045572     7.4074197
#   -3.130435     7.2118545  -15.448091     4.136127    -6.293926
#    9.502879    -5.3641586    6.619323     1.5061382   -1.7083994
#   -3.285543     7.676069    -9.124614    -0.658288    -0.22298487
#    1.3961397   -6.960764     4.032412     2.008322    -2.8119197 ]
# [[-51.242413    49.093845   -18.26149      3.055037   -22.694397
#     4.807211   -19.459581    14.904933   -29.962736    -3.8382246
#    -9.103179    17.830744   -22.41513     14.5221     -16.380196
#     4.0303774  -18.906586     9.933028    -8.045572     7.4074197
#    -3.130435     7.2118545  -15.448091     4.136127    -6.293926
#     9.502879    -5.3641586    6.619323     1.5061382   -1.7083994
#    -3.285543     7.676069    -9.124614    -0.658288    -0.22298487
#     1.3961397   -6.960764     4.032412     2.008322    -2.8119197 ]]
# (1, 40)
# 1/1 [==============================] - 0s 20ms/step
# [1]
# array(['gear_fault'], dtype='<U10')
